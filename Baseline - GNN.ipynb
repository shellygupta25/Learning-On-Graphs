# %%
import os
import pandas as pd
import datetime as dt
import numpy as np
import time 
import torch
import pickle
from torch_geometric.data import Data
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score
from torch_geometric.utils import negative_sampling
from sklearn.metrics import precision_score, accuracy_score,f1_score,roc_auc_score
import warnings
warnings.filterwarnings("ignore")
# Out:
# /home/shellygupta/.local/lib/python3.8/site-packages/torch_geometric/typing.py:42: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: libcudart.so.11.0: cannot open shared object file: No such file or directory
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
class Net(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def encode(self, x, edge_index):
        x = self.conv1(x, edge_index).relu()
        return self.conv2(x, edge_index)

    def decode(self, z, edge_label_index):
        return (z[edge_label_index[0]] * z[edge_label_index[1]]).sum(
            dim=-1
        )  # product of a pair of nodes on each edge

    def decode_all(self, z):
        prob_adj = z @ z.t()
        return (prob_adj > 0).nonzero(as_tuple=False).t()
    

def train_link_predictor(
    model, train_data, val_data, optimizer, criterion, n_epochs=100
):
    best_model = model
    best_val_auc = 0
    val_auc_list = []
    train_loss_list = []
    for epoch in range(1, n_epochs + 1):

        model.train()
        optimizer.zero_grad()
        z = model.encode(train_data.x, train_data.edge_index)

        # sampling training negatives for every training epoch
        neg_edge_index = negative_sampling(
            edge_index=train_data.edge_index, num_nodes=train_data.num_nodes,
            num_neg_samples=train_data.edge_label_index.size(1), method='sparse')

        edge_label_index = torch.cat(
            [train_data.edge_label_index, neg_edge_index],
            dim=-1,
        )
        edge_label = torch.cat([
            train_data.edge_label,
            train_data.edge_label.new_zeros(neg_edge_index.size(1))
        ], dim=0)

        out = model.decode(z, edge_label_index).view(-1)
        loss = criterion(out, edge_label)
        loss.backward()
        optimizer.step()

        val_auc = eval_link_predictor(model, val_data)
        val_auc_list.append(val_auc)
        if (val_auc > best_val_auc):
            best_model = model
            best_val_auc = val_auc
            line = "Epoch: "+str(epoch) + "\tTrain Loss: "+str(loss) + "\tVal AUC: "+str(best_val_auc)
            
        if epoch%10 == 0:
            print(f"Epoch: {epoch:03d}, Train Loss: {loss:.3f}, Val AUC: {val_auc:.3f}")
        #train_loss_list.append({loss:.3f})
        
    print("\n\n for best model :\n",line)
    train_loss_list.append(loss)
    return best_model,val_auc_list,train_loss_list #,train_auc_list


@torch.no_grad()
def eval_link_predictor(model, data):
    with torch.no_grad():
        model.eval()
        z = model.encode(data.x, data.edge_index)
        out = model.decode(z, data.edge_label_index).view(-1).sigmoid()

    return roc_auc_score(data.edge_label.cpu().numpy(), out.cpu().numpy())

# %%
#user set params
dir_path = "WSJ split data files"
dbname = "WSJ"
node_feature_dir_path = "WSJ node features"
epochs = 100

# %%
# downloading  node_embeddings 
node_embeddings = pickle.load(open(node_feature_dir_path + "/node_embeddings_for_pytorch_models_excluding_split_"+str(test_file_no)+".p","rb"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2616837/2244634047.py in <module>
#       1 # downloading  node_embeddings
# ----> 2 node_embeddings = pickle.load(open(node_feature_dir_path + "/node_embeddings_for_pytorch_models_excluding_split_"+str(test_file_no)+".p","rb"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'WSJ node features/node_embeddings_for_pytorch_models_excluding_split_1.p'

# %%
for split_no in range(1,11,1):
    test_file_no = split_no
    print("Test no ", test_file_no, " going on")
    print("\n\n\n Test file no : ",test_file_no)
    train_df = pd.DataFrame()
    for i in range(1,11,1):
        if i != test_file_no:
            df = pd.read_csv(dir_path+"/WSJ_positive_edges_split_"+str(i)+".csv") 
            train_df = train_df.append(df, ignore_index=True)
            del df
        
            
    train_df = train_df.drop(['layer', 'weight',"sign"], axis=1)
    
    #making node_id variables continuous
    temp_node_no = pickle.load(open("node_id_into_continuous_node_ids.p","rb"))
    
    # collecting all positive edges
    train_df['src'] = [temp_node_no[i] for i in train_df['src']]
    train_df['dest'] = [temp_node_no[i] for i in train_df['dest']]
    final_edge_list = [torch.Tensor([train_df['src']]),torch.Tensor([train_df['dest']])]
    final_edge_list = torch.cat(tuple(final_edge_list),dim=0)  
    
    # downloading  node_embeddings 
    node_embeddings = pickle.load(open(node_feature_dir_path + "/node_embeddings_for_pytorch_models_excluding_split_"+str(test_file_no)+".p","rb"))
    
    #making training and val graphs
    data = Data()
    data.x = node_embeddings
    data.edge_index = final_edge_list.type(torch.int64)

    split = T.RandomLinkSplit(
        num_val=0.05,
        num_test=0.0,
        is_undirected=True,
        add_negative_train_samples=False,
        neg_sampling_ratio=1.0)
    train_data, val_data, test_data = split(data)
    
    del train_df, node_embeddings, final_edge_list, data
    
    model = Net(8, 3, 2) #.to(device)
    optimizer = torch.optim.Adam(params=model.parameters(), lr=0.001)
    criterion = torch.nn.BCEWithLogitsLoss()
    
    curr = time.time()
    best_model,_,_ = train_link_predictor(model, train_data, val_data, optimizer, criterion,n_epochs=epochs)
    timetaken = time.time()-curr
    print("time taken for training : ",timetaken)
    print("time taken for per epoch : ",timetaken/epochs)
    
    torch.save(best_model.state_dict(), "my_"+str(dbname)+"_GNN_model_state_dict_"+str(test_file_no))
    torch.save(best_model, "my_"+str(dbname)+"_GNN_whole_model_"+str(test_file_no))
    
    del model
# Out:
# Test no  1  going on
#
#
#
#  Test file no :  1
# Epoch: 010, Train Loss: 0.612, Val AUC: 0.906
# Epoch: 020, Train Loss: 0.596, Val AUC: 0.905
# Epoch: 030, Train Loss: 0.585, Val AUC: 0.904
# Epoch: 040, Train Loss: 0.578, Val AUC: 0.901
# Epoch: 050, Train Loss: 0.573, Val AUC: 0.899
# Epoch: 060, Train Loss: 0.572, Val AUC: 0.896
# Epoch: 070, Train Loss: 0.569, Val AUC: 0.893
# Epoch: 080, Train Loss: 0.568, Val AUC: 0.891
# Epoch: 090, Train Loss: 0.566, Val AUC: 0.889
# Epoch: 100, Train Loss: 0.564, Val AUC: 0.887
#
#
#  for best model :
#  Epoch: 5	Train Loss: tensor(0.6205, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.9061334437850556
# time taken for training :  120.36720037460327
# time taken for per epoch :  1.2036720037460327
# Test no  2  going on
#
#
#
#  Test file no :  2
# Epoch: 010, Train Loss: 0.659, Val AUC: 0.908
# Epoch: 020, Train Loss: 0.649, Val AUC: 0.910
# Epoch: 030, Train Loss: 0.638, Val AUC: 0.912
# Epoch: 040, Train Loss: 0.626, Val AUC: 0.913
# Epoch: 050, Train Loss: 0.614, Val AUC: 0.913
# Epoch: 060, Train Loss: 0.603, Val AUC: 0.914
# Epoch: 070, Train Loss: 0.593, Val AUC: 0.913
# Epoch: 080, Train Loss: 0.586, Val AUC: 0.913
# Epoch: 090, Train Loss: 0.580, Val AUC: 0.912
# Epoch: 100, Train Loss: 0.576, Val AUC: 0.911
#
#
#  for best model :
#  Epoch: 59	Train Loss: tensor(0.6042, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.9135034483349344
# time taken for training :  120.26893782615662
# time taken for per epoch :  1.2026893782615662
# Test no  3  going on
#
#
#
#  Test file no :  3
# Epoch: 010, Train Loss: 0.679, Val AUC: 0.411
# Epoch: 020, Train Loss: 0.677, Val AUC: 0.514
# Epoch: 030, Train Loss: 0.675, Val AUC: 0.573
# Epoch: 040, Train Loss: 0.673, Val AUC: 0.605
# Epoch: 050, Train Loss: 0.671, Val AUC: 0.623
# Epoch: 060, Train Loss: 0.669, Val AUC: 0.631
# Epoch: 070, Train Loss: 0.668, Val AUC: 0.635
# Epoch: 080, Train Loss: 0.666, Val AUC: 0.637
# Epoch: 090, Train Loss: 0.664, Val AUC: 0.639
# Epoch: 100, Train Loss: 0.663, Val AUC: 0.640
#
#
#  for best model :
#  Epoch: 100	Train Loss: tensor(0.6629, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.6395653246542091
# time taken for training :  121.00283074378967
# time taken for per epoch :  1.2100283074378968
# Test no  4  going on
#
#
#
#  Test file no :  4
# Epoch: 010, Train Loss: 0.661, Val AUC: 0.575
# Epoch: 020, Train Loss: 0.660, Val AUC: 0.647
# Epoch: 030, Train Loss: 0.659, Val AUC: 0.677
# Epoch: 040, Train Loss: 0.658, Val AUC: 0.697
# Epoch: 050, Train Loss: 0.656, Val AUC: 0.723
# Epoch: 060, Train Loss: 0.654, Val AUC: 0.759
# Epoch: 070, Train Loss: 0.651, Val AUC: 0.798
# Epoch: 080, Train Loss: 0.647, Val AUC: 0.832
# Epoch: 090, Train Loss: 0.643, Val AUC: 0.857
# Epoch: 100, Train Loss: 0.637, Val AUC: 0.875
#
#
#  for best model :
#  Epoch: 100	Train Loss: tensor(0.6375, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.875178151313375
# time taken for training :  119.90683436393738
# time taken for per epoch :  1.1990683436393739
# Test no  5  going on
#
#
#
#  Test file no :  5
# Epoch: 010, Train Loss: 0.690, Val AUC: 0.400
# Epoch: 020, Train Loss: 0.687, Val AUC: 0.424
# Epoch: 030, Train Loss: 0.684, Val AUC: 0.453
# Epoch: 040, Train Loss: 0.681, Val AUC: 0.491
# Epoch: 050, Train Loss: 0.677, Val AUC: 0.540
# Epoch: 060, Train Loss: 0.672, Val AUC: 0.598
# Epoch: 070, Train Loss: 0.666, Val AUC: 0.663
# Epoch: 080, Train Loss: 0.660, Val AUC: 0.728
# Epoch: 090, Train Loss: 0.652, Val AUC: 0.786
# Epoch: 100, Train Loss: 0.644, Val AUC: 0.833
#
#
#  for best model :
#  Epoch: 100	Train Loss: tensor(0.6437, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.8332025881715042
# time taken for training :  119.2694902420044
# time taken for per epoch :  1.192694902420044
# Test no  6  going on
#
#
#
#  Test file no :  6
# Epoch: 010, Train Loss: 0.557, Val AUC: 0.914
# Epoch: 020, Train Loss: 0.548, Val AUC: 0.914
# Epoch: 030, Train Loss: 0.540, Val AUC: 0.914
# Epoch: 040, Train Loss: 0.535, Val AUC: 0.914
# Epoch: 050, Train Loss: 0.530, Val AUC: 0.913
# Epoch: 060, Train Loss: 0.527, Val AUC: 0.913
# Epoch: 070, Train Loss: 0.523, Val AUC: 0.913
# Epoch: 080, Train Loss: 0.521, Val AUC: 0.913
# Epoch: 090, Train Loss: 0.518, Val AUC: 0.913
# Epoch: 100, Train Loss: 0.516, Val AUC: 0.913
#
#
#  for best model :
#  Epoch: 18	Train Loss: tensor(0.5495, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.9141926204951478
# time taken for training :  120.57546138763428
# time taken for per epoch :  1.2057546138763429
# Test no  7  going on
#
#
#
#  Test file no :  7
# Epoch: 010, Train Loss: 0.614, Val AUC: 0.900
# Epoch: 020, Train Loss: 0.606, Val AUC: 0.907
# Epoch: 030, Train Loss: 0.599, Val AUC: 0.913
# Epoch: 040, Train Loss: 0.593, Val AUC: 0.916
# Epoch: 050, Train Loss: 0.587, Val AUC: 0.918
# Epoch: 060, Train Loss: 0.581, Val AUC: 0.920
# Epoch: 070, Train Loss: 0.575, Val AUC: 0.921
# Epoch: 080, Train Loss: 0.569, Val AUC: 0.922
# Epoch: 090, Train Loss: 0.564, Val AUC: 0.924
# Epoch: 100, Train Loss: 0.557, Val AUC: 0.927
#
#
#  for best model :
#  Epoch: 100	Train Loss: tensor(0.5574, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.9268657884941336
# time taken for training :  121.23943662643433
# time taken for per epoch :  1.2123943662643433
# Test no  8  going on
#
#
#
#  Test file no :  8
# Epoch: 010, Train Loss: 0.758, Val AUC: 0.357
# Epoch: 020, Train Loss: 0.741, Val AUC: 0.411
# Epoch: 030, Train Loss: 0.725, Val AUC: 0.478
# Epoch: 040, Train Loss: 0.712, Val AUC: 0.522
# Epoch: 050, Train Loss: 0.702, Val AUC: 0.552
# Epoch: 060, Train Loss: 0.694, Val AUC: 0.575
# Epoch: 070, Train Loss: 0.687, Val AUC: 0.593
# Epoch: 080, Train Loss: 0.681, Val AUC: 0.607
# Epoch: 090, Train Loss: 0.676, Val AUC: 0.615
# Epoch: 100, Train Loss: 0.672, Val AUC: 0.621
#
#
#  for best model :
#  Epoch: 100	Train Loss: tensor(0.6725, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.6207927141794556
# time taken for training :  119.76287317276001
# time taken for per epoch :  1.1976287317276002
# Test no  9  going on
#
#
#
#  Test file no :  9
# Epoch: 010, Train Loss: 0.674, Val AUC: 0.402
# Epoch: 020, Train Loss: 0.672, Val AUC: 0.442
# Epoch: 030, Train Loss: 0.670, Val AUC: 0.498
# Epoch: 040, Train Loss: 0.668, Val AUC: 0.556
# Epoch: 050, Train Loss: 0.666, Val AUC: 0.593
# Epoch: 060, Train Loss: 0.665, Val AUC: 0.616
# Epoch: 070, Train Loss: 0.663, Val AUC: 0.624
# Epoch: 080, Train Loss: 0.662, Val AUC: 0.629
# Epoch: 090, Train Loss: 0.661, Val AUC: 0.631
# Epoch: 100, Train Loss: 0.660, Val AUC: 0.632
#
#
#  for best model :
#  Epoch: 100	Train Loss: tensor(0.6600, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.6318242315266275
# time taken for training :  120.66897773742676
# time taken for per epoch :  1.2066897773742675
# Test no  10  going on
#
#
#
#  Test file no :  10
# Epoch: 010, Train Loss: 0.659, Val AUC: 0.628
# Epoch: 020, Train Loss: 0.653, Val AUC: 0.713
# Epoch: 030, Train Loss: 0.645, Val AUC: 0.779
# Epoch: 040, Train Loss: 0.637, Val AUC: 0.822
# Epoch: 050, Train Loss: 0.629, Val AUC: 0.852
# Epoch: 060, Train Loss: 0.621, Val AUC: 0.872
# Epoch: 070, Train Loss: 0.612, Val AUC: 0.887
# Epoch: 080, Train Loss: 0.604, Val AUC: 0.897
# Epoch: 090, Train Loss: 0.596, Val AUC: 0.903
# Epoch: 100, Train Loss: 0.589, Val AUC: 0.907
#
#
#  for best model :
#  Epoch: 100	Train Loss: tensor(0.5891, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>)	Val AUC: 0.9066517707199966
# time taken for training :  121.05819582939148
# time taken for per epoch :  1.2105819582939148
